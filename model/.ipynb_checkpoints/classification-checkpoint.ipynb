# %%
# !conda list
# Out:
# # packages in environment at C:\Users\foxir\miniconda3\envs\gunshot_tf:
# #
# # Name                    Version                   Build  Channel
# absl-py                   2.1.0                    pypi_0    pypi
# asttokens                 3.0.0                    pypi_0    pypi
# astunparse                1.6.3                    pypi_0    pypi
# audiomentations           0.38.0                   pypi_0    pypi
# audioread                 3.0.1                    pypi_0    pypi
# bzip2                     1.0.8                h2466b09_7    conda-forge
# ca-certificates           2024.12.14           h56e8100_0    conda-forge
# cachetools                5.5.0                    pypi_0    pypi
# certifi                   2024.12.14               pypi_0    pypi
# cffi                      1.17.1                   pypi_0    pypi
# charset-normalizer        3.4.0                    pypi_0    pypi
# colorama                  0.4.6                    pypi_0    pypi
# comm                      0.2.2                    pypi_0    pypi
# contourpy                 1.3.1                    pypi_0    pypi
# cudatoolkit               11.2.2              h7d7167e_13    conda-forge
# cudnn                     8.1.0.77             h3e0f4f4_0    conda-forge
# cycler                    0.12.1                   pypi_0    pypi
# debugpy                   1.8.11                   pypi_0    pypi
# decorator                 5.1.1                    pypi_0    pypi
# exceptiongroup            1.2.2                    pypi_0    pypi
# executing                 2.1.0                    pypi_0    pypi
# flatbuffers               24.3.25                  pypi_0    pypi
# fonttools                 4.55.3                   pypi_0    pypi
# gast                      0.6.0                    pypi_0    pypi
# google-auth               2.37.0                   pypi_0    pypi
# google-auth-oauthlib      0.4.6                    pypi_0    pypi
# google-pasta              0.2.0                    pypi_0    pypi
# grpcio                    1.68.1                   pypi_0    pypi
# h5py                      3.12.1                   pypi_0    pypi
# idna                      3.10                     pypi_0    pypi
# ipykernel                 6.29.5                   pypi_0    pypi
# ipython                   8.30.0                   pypi_0    pypi
# jedi                      0.19.2                   pypi_0    pypi
# joblib                    1.4.2                    pypi_0    pypi
# jupyter-client            8.6.3                    pypi_0    pypi
# jupyter-core              5.7.2                    pypi_0    pypi
# keras                     2.8.0                    pypi_0    pypi
# keras-preprocessing       1.1.2                    pypi_0    pypi
# kiwisolver                1.4.7                    pypi_0    pypi
# lazy-loader               0.4                      pypi_0    pypi
# libclang                  18.1.1                   pypi_0    pypi
# libffi                    3.4.2                h8ffe710_5    conda-forge
# liblzma                   5.6.3                h2466b09_1    conda-forge
# liblzma-devel             5.6.3                h2466b09_1    conda-forge
# librosa                   0.10.2.post1             pypi_0    pypi
# libsqlite                 3.47.2               h67fdade_0    conda-forge
# libzlib                   1.3.1                h2466b09_2    conda-forge
# llvmlite                  0.43.0                   pypi_0    pypi
# markdown                  3.7                      pypi_0    pypi
# markupsafe                3.0.2                    pypi_0    pypi
# matplotlib                3.10.0                   pypi_0    pypi
# matplotlib-inline         0.1.7                    pypi_0    pypi
# msgpack                   1.1.0                    pypi_0    pypi
# nest-asyncio              1.6.0                    pypi_0    pypi
# numba                     0.60.0                   pypi_0    pypi
# numpy                     1.26.4                   pypi_0    pypi
# numpy-minmax              0.3.1                    pypi_0    pypi
# numpy-rms                 0.4.2                    pypi_0    pypi
# oauthlib                  3.2.2                    pypi_0    pypi
# openssl                   3.4.0                h2466b09_0    conda-forge
# opt-einsum                3.4.0                    pypi_0    pypi
# packaging                 24.2                     pypi_0    pypi
# parso                     0.8.4                    pypi_0    pypi
# pillow                    11.0.0                   pypi_0    pypi
# pip                       24.3.1             pyh8b19718_0    conda-forge
# platformdirs              4.3.6                    pypi_0    pypi
# pooch                     1.8.2                    pypi_0    pypi
# prompt-toolkit            3.0.48                   pypi_0    pypi
# protobuf                  3.20.0                   pypi_0    pypi
# psutil                    6.1.0                    pypi_0    pypi
# pure-eval                 0.2.3                    pypi_0    pypi
# pyasn1                    0.6.1                    pypi_0    pypi
# pyasn1-modules            0.4.1                    pypi_0    pypi
# pycparser                 2.22                     pypi_0    pypi
# pygments                  2.18.0                   pypi_0    pypi
# pyparsing                 3.2.0                    pypi_0    pypi
# python                    3.10.2          hcf16a7b_4_cpython    conda-forge
# python-dateutil           2.9.0.post0              pypi_0    pypi
# pywin32                   308                      pypi_0    pypi
# pyzmq                     26.2.0                   pypi_0    pypi
# requests                  2.32.3                   pypi_0    pypi
# requests-oauthlib         2.0.0                    pypi_0    pypi
# rsa                       4.9                      pypi_0    pypi
# scikit-learn              1.6.0                    pypi_0    pypi
# scipy                     1.12.0                   pypi_0    pypi
# setuptools                75.6.0             pyhff2d567_1    conda-forge
# six                       1.17.0                   pypi_0    pypi
# soundfile                 0.13.0                   pypi_0    pypi
# soxr                      0.5.0.post1              pypi_0    pypi
# spec-augment              0.0.3                    pypi_0    pypi
# sqlite                    3.47.2               h2466b09_0    conda-forge
# stack-data                0.6.3                    pypi_0    pypi
# tensorboard               2.8.0                    pypi_0    pypi
# tensorboard-data-server   0.6.1                    pypi_0    pypi
# tensorboard-plugin-wit    1.8.1                    pypi_0    pypi
# tensorflow                2.8.0                    pypi_0    pypi
# tensorflow-io             0.25.0                   pypi_0    pypi
# tensorflow-io-gcs-filesystem 0.25.0                   pypi_0    pypi
# termcolor                 2.5.0                    pypi_0    pypi
# tf-estimator-nightly      2.8.0.dev2021122109          pypi_0    pypi
# threadpoolctl             3.5.0                    pypi_0    pypi
# tk                        8.6.13               h5226925_1    conda-forge
# tornado                   6.4.2                    pypi_0    pypi
# traitlets                 5.14.3                   pypi_0    pypi
# typing-extensions         4.12.2                   pypi_0    pypi
# tzdata                    2024b                hc8b5060_0    conda-forge
# ucrt                      10.0.22621.0         h57928b3_1    conda-forge
# urllib3                   2.2.3                    pypi_0    pypi
# vc                        14.3                ha32ba9b_23    conda-forge
# vc14_runtime              14.42.34433         he29a5d6_23    conda-forge
# vs2015_runtime            14.42.34433         hdffcdeb_23    conda-forge
# wcwidth                   0.2.13                   pypi_0    pypi
# werkzeug                  3.1.3                    pypi_0    pypi
# wheel                     0.45.1             pyhd8ed1ab_1    conda-forge
# wrapt                     1.17.0                   pypi_0    pypi
# xz                        5.6.3                h208afaa_1    conda-forge
# xz-tools                  5.6.3                h2466b09_1    conda-forge

# %%
import os
from matplotlib import pyplot as plt
import tensorflow as tf
import tensorflow_io as tfio
import numpy as np
import glob
import random

# %%
# !python -c "import tensorflow as tf; print(tf.config.list_physical_devices('GPU'))"
# Out:
# [PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')]

# %%
data = os.path.join('belize-data')
val_NEG = os.path.join('belize-data', 'Validation data', 'Background')
val_POS = os.path.join('belize-data', 'Validation data', 'Gunshot')
model_dir = os.path.join('C', 'Users', 'foxir', 'OneDrive', 'Desktop', 'Smart Rock', 'gunshot-detection-models', '1-5-25', '1-5-25,B-Dataset,30mPara,4E.keras')
outputs_dir = os.path.join('outputs')
background_wav = os.path.join('belize-data', 'Training data', 'Background', '5B1E8E78.wav')
gunshot_wav = os.path.join('belize-data', 'Training data', 'Gunshot', '5B9FE44F_3709e9f5ff-aa0a-4ba9-9e61-d64d9666527614b02738-a1c6-43fb-b13e-0651261d1ca002c1d2c0-064c-4f43-b3a6-9da25d3e0930.wav')

# %%
loaded_model = tf.keras.models.load_model('1-5-25,B-Dataset,30mPara,4E.keras')
# Out:
# ---------------------------------------------------------------------------
# ResourceExhaustedError                    Traceback (most recent call last)
# Cell In[145], line 1
# ----> 1 loaded_model = tf.keras.models.load_model('1-5-25,B-Dataset,30mPara,4E.keras')
#
# File ~\miniconda3\envs\gunshot_tf\lib\site-packages\keras\utils\traceback_utils.py:67, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#      65 except Exception as e:  # pylint: disable=broad-except
#      66   filtered_tb = _process_traceback_frames(e.__traceback__)
# ---> 67   raise e.with_traceback(filtered_tb) from None
#      68 finally:
#      69   del filtered_tb
#
# File ~\miniconda3\envs\gunshot_tf\lib\site-packages\keras\backend.py:1920, in RandomGenerator.random_uniform(self, shape, minval, maxval, dtype)
#    1917 if self._generator:
#    1918   return self._generator.uniform(
#    1919       shape=shape, minval=minval, maxval=maxval, dtype=dtype)
# -> 1920 return tf.random.uniform(
#    1921     shape=shape, minval=minval, maxval=maxval, dtype=dtype,
#    1922     seed=self.make_legacy_seed())
#
# ResourceExhaustedError: OOM when allocating tensor with shape[235200,128] and type float on /job:localhost/replica:0/task:0/device:GPU:0 by allocator GPU_0_bfc [Op:RandomUniform]

# %%
data = [('file1',1),('file2',1),('file3',1),('file4',0)]

results = []

for i in data:
    filename = i[0]
    label = i[1]
    yhat = label*0.75
    results.append((filename, yhat, label))

# %%
results
# Out:
# [('file1', 0.75, 1), ('file2', 0.75, 1), ('file3', 0.75, 1), ('file4', 0.0, 0)]

# %%
val_neg = glob.glob(val_NEG+'/*.wav')
val_pos = glob.glob(val_POS+'/*.wav')

# %%
print(len(val_neg))
print(len(val_pos))
# Out:
# 7040
# 150

# %%
val_neg = list(zip(val_neg, [0]*len(val_neg)))
val_pos = list(zip(val_pos, [1]*len(val_pos)))

# %%
val_data = val_neg+val_pos

# %%
random.shuffle(val_data)

# %%
val_data
# Out:
# [('belize-data\\Validation data\\Background\\5AFA283D.WAV', 0),
#  ('belize-data\\Validation data\\Background\\5ADA3A79.WAV', 0),
#  ('belize-data\\Validation data\\Gunshot\\5B6659F9_14f4fa2843-c929-4b4b-aaf9-fe113efaf214087fca4e-bcf7-450e-ac7d-fed05c03b0166ba9869c-01fd-47aa-975b-2234f823430f.WAV',
#   1),
#  ('belize-data\\Validation data\\Background\\5AE466AC.WAV', 0),
#  ('belize-data\\Validation data\\Background\\6018480D.WAV', 0),
#  ('belize-data\\Validation data\\Background\\600BE722.WAV', 0),
#  ('belize-data\\Validation data\\Background\\5ACDFAB2.WAV', 0),
#  ('belize-data\\Validation data\\Background\\60119D82.WAV', 0),
#  ('belize-data\\Validation data\\Background\\5AFC73C9.WAV', 0),
#  ('belize-data\\Validation data\\Background\\5B182CFA.WAV', 0),
#  ('belize-data\\Validation data\\Background\\5AE74CEC.WAV', 0),
#  ('belize-data\\Validation data\\Background\\5AF74DC1.WAV', 0),
#  ('belize-data\\Validation data\\Background\\601D8384.WAV', 0),
#  ('belize-data\\Validation data\\Background\\5B044582.WAV', 0),
#  ('belize-data\\Validation data\\Background\\5B1E80E3.WAV', 0),
#  ('belize-data\\Validation data\\Background\\5B01B081.WAV', 0),
#  ('belize-data\\Validation data\\Background\\5AD8CE8C.WAV', 0),
#  ('belize-data\\Validation data\\Background\\600FB1A8.WAV', 0),
#  ('belize-data\\Validation data\\Background\\5AF32015.WAV', 0),
#  ('belize-data\\Validation data\\Background\\5B1A3778.WAV', 0),
#  ('belize-data\\Validation data\\Background\\5AF9AFAD.WAV', 0),
#  ('belize-data\\Validation data\\Background\\60216199.WAV', 0),
#  ('belize-data\\Validation data\\Background\\5B135222.WAV', 0),
#  ('belize-data\\Validation data\\Background\\5AFDE889.WAV', 0),
#  ('belize-data\\Validation data\\Background\\6021DA33.WAV', 0),
#  ('belize-data\\Validation data\\Background\\5B0B3F62.WAV', 0),
#  ('belize-data\\Validation data\\Background\\5AFC83F4.WAV', 0),
#  ('belize-data\\Validation data\\Background\\5B1B35B6.WAV', 0),
#  ('belize-data\\Validation data\\Background\\5B192956.WAV', 0),
#  ('belize-data\\Validation data\\Background\\5AFC73CE.WAV', 0),
#  ('belize-data\\Validation data\\Background\\5B094081.WAV', 0),
#  ('belize-data\\Validation data\\Gunshot\\58FBBD40b226dd58-51a2-4cdc-b0be-9114f90f4d31.WAV',
#   1),
#  ('belize-data\\Validation data\\Background\\5AEC4F48.WAV', 0),
#  ('belize-data\\Validation data\\Background\\5B1A95BE.WAV', 0),
#  ('belize-data\\Validation data\\Background\\5AEF1B23.WAV', 0),
#  ('belize-data\\Validation data\\Background\\5AFD4B97.WAV', 0),
#  ('belize-data\\Validation data\\Background\\5AEC8885.WAV', 0),
#  ('belize-data\\Validation data\\Background\\5AF0961C.WAV', 0),
#  ('belize-data\\Validation data\\Background\\5AF2B8F0.WAV', 0),
#  ('belize-data\\Validation data\\Background\\60234E58.WAV', 0),
#  ('belize-data\\Validation data\\Background\\5AE65F73.WAV', 0),
#  ('belize-data\\Validation data\\Background\\5B0D3C1B.WAV', 0),
#  ('belize-data\\Validation data\\Background\\5AF096FB.WAV', 0),
#  ('belize-data\\Validation data\\Background\\60227B88.WAV', 0),
#  ('belize-data\\Validation data\\Background\\600C643D.WAV', 0),
#  ('belize-data\\Validation data\\Background\\5AD7E540.WAV', 0),
#  ('belize-data\\Validation data\\Background\\5B129E36.WAV', 0),
#  ('belize-data\\Validation data\\Background\\60148E56.WAV', 0),
#  ('belize-data\\Validation data\\Gunshot\\58FBD45A54c6c63a-9792-4af7-bb0b-b2cbe6dc2eea.WAV',
#   1),
#  ('belize-data\\Validation data\\Background\\5B0F02F1.WAV', 0),
#  ('belize-data\\Validation data\\Background\\602334C6.WAV', 0),
#  ('belize-data\\Validation data\\Background\\5AD16ABC.WAV', 0),
#  ('belize-data\\Validation data\\Background\\5AF5841E.WAV', 0),
#  ('belize-data\\Validation data\\Background\\5B12A43A.WAV', 0),
#  ('belize-data\\Validation data\\Background\\5AE3C68D.WAV', 0),
#  ('belize-data\\Validation data\\Background\\5AEA560E.WAV', 0),
#  ('belize-data\\Validation data\\Background\\5AF22CDD.WAV', 0),
#  ('belize-data\\Validation data\\Background\\5B041105.WAV', 0),
#  ('belize-data\\Validation data\\Background\\6019BB8D.WAV', 0),
#  ('belize-data\\Validation data\\Background\\5AEE3EFA.WAV', 0),
#  ('belize-data\\Validation data\\Background\\5AEA18E8.WAV', 0),
#  ('belize-data\\Validation data\\Background\\5AE9AAC1.WAV', 0),
#  ('belize-data\\Validation data\\Background\\5ADB8CD0.WAV', 0),
#  ('belize-data\\Validation data\\Background\\5AFE282C.WAV', 0),
#  ('belize-data\\Validation data\\Background\\5ADF7739.WAV', 0),
#  ('belize-data\\Validation data\\Background\\601EFEFD.WAV', 0),
#  ('belize-data\\Validation data\\Background\\5B08191E.WAV', 0),
#  ('belize-data\\Validation data\\Background\\5AE9AF73.WAV', 0),
#  ('belize-data\\Validation data\\Background\\5AEF147B.WAV', 0),
#  ('belize-data\\Validation data\\Background\\5B1C0D2A.WAV', 0),
#  ('belize-data\\Validation data\\Background\\5AEF3765.WAV', 0),
#  ('belize-data\\Validation data\\Background\\600AF713.WAV', 0),
#  ('belize-data\\Validation data\\Background\\601F4B04.WAV', 0),
#  ('belize-data\\Validation data\\Background\\601B78DA.WAV', 0),
#  ('belize-data\\Validation data\\Background\\6020E84B.WAV', 0),
#  ('belize-data\\Validation data\\Background\\5AF9CF61.WAV', 0),
#  ('belize-data\\Validation data\\Background\\5B043935.WAV', 0),
#  ('belize-data\\Validation data\\Background\\600AC1C6.WAV', 0),
#  ('belize-data\\Validation data\\Background\\601C7386.WAV', 0),
#  ('belize-data\\Validation data\\Background\\601BEE98.WAV', 0),
#  ('belize-data\\Validation data\\Background\\6015609F.WAV', 0),
#  ('belize-data\\Validation data\\Background\\5AE10945.WAV', 0),
#  ('belize-data\\Validation data\\Background\\5AFC9C28.WAV', 0),
#  ('belize-data\\Validation data\\Background\\5AEC5EA0.WAV', 0),
#  ('belize-data\\Validation data\\Background\\5B058963.WAV', 0),
#  ('belize-data\\Validation data\\Background\\5AECAFB9.WAV', 0),
#  ('belize-data\\Validation data\\Background\\5AEE708D.WAV', 0),
#  ('belize-data\\Validation data\\Background\\5B177C4D.WAV', 0),
#  ('belize-data\\Validation data\\Background\\5AF8D2F6.WAV', 0),
#  ('belize-data\\Validation data\\Background\\60165D04.WAV', 0),
#  ('belize-data\\Validation data\\Background\\5B1AE844.WAV', 0),
#  ('belize-data\\Validation data\\Background\\5B0A5C18.WAV', 0),
#  ('belize-data\\Validation data\\Background\\5ADBAC47.WAV', 0),
#  ('belize-data\\Validation data\\Background\\60233163.WAV', 0),
#  ('belize-data\\Validation data\\Background\\60108609.WAV', 0),
#  ('belize-data\\Validation data\\Background\\5B105027.WAV', 0),
#  ('belize-data\\Validation data\\Background\\6019886E.WAV', 0),
#  ('belize-data\\Validation data\\Background\\602288A6.WAV', 0),
#  ('belize-data\\Validation data\\Background\\5AF561BD.WAV', 0),
#  ('belize-data\\Validation data\\Background\\5B1696DF.WAV', 0),
#  ('belize-data\\Validation data\\Background\\5AE21D28.WAV', 0),
#  ('belize-data\\Validation data\\Background\\5ADAD8C5.WAV', 0),
#  ('belize-data\\Validation data\\Background\\5AF0B598.WAV', 0),
#  ('belize-data\\Validation data\\Background\\601C491F.WAV', 0),
#  ('belize-data\\Validation data\\Background\\5B12A3D4.WAV', 0),
#  ('belize-data\\Validation data\\Background\\5AD7EBE9.WAV', 0),
#  ('belize-data\\Validation data\\Background\\5B19AB1D.WAV', 0),
#  ('belize-data\\Validation data\\Background\\5B0074D0.WAV', 0),
#  ('belize-data\\Validation data\\Background\\5AD7AD06.WAV', 0),
#  ('belize-data\\Validation data\\Background\\602182F8.WAV', 0),
#  ('belize-data\\Validation data\\Background\\5AF62D47.WAV', 0),
#  ('belize-data\\Validation data\\Background\\5AE9BB8C.WAV', 0),
#  ('belize-data\\Validation data\\Background\\5B0F6933.WAV', 0),
#  ('belize-data\\Validation data\\Background\\5B005053.WAV', 0),
#  ('belize-data\\Validation data\\Background\\5AF2B281.WAV', 0),
#  ('belize-data\\Validation data\\Background\\5B17E1E0.WAV', 0),
#  ('belize-data\\Validation data\\Background\\5ADD4CA5.WAV', 0),
#  ('belize-data\\Validation data\\Background\\5B1ACFAE.WAV', 0),
#  ('belize-data\\Validation data\\Background\\6010BB87.WAV', 0),
#  ('belize-data\\Validation data\\Background\\5AF0E979.WAV', 0),
#  ('belize-data\\Validation data\\Background\\5ACC24DC.WAV', 0),
#  ('belize-data\\Validation data\\Background\\5B070A27.WAV', 0),
#  ('belize-data\\Validation data\\Background\\60228969.WAV', 0),
#  ('belize-data\\Validation data\\Background\\601C8038.WAV', 0),
#  ('belize-data\\Validation data\\Background\\5AFE98BC.WAV', 0),
#  ('belize-data\\Validation data\\Background\\5AE3DBF0.WAV', 0),
#  ('belize-data\\Validation data\\Background\\5B1816A5.WAV', 0),
#  ('belize-data\\Validation data\\Background\\5AF97101.WAV', 0),
#  ('belize-data\\Validation data\\Background\\5AF20DDB.WAV', 0),
#  ('belize-data\\Validation data\\Background\\6018E55F.WAV', 0),
#  ('belize-data\\Validation data\\Background\\5B0F5CAE.WAV', 0),
#  ('belize-data\\Validation data\\Background\\600F24BF.WAV', 0),
#  ('belize-data\\Validation data\\Background\\5B
# Mel Filterbank Shape: (129, 64)
# Mel Spectrogram Shape1: (249, 64)
# Mel Spectrogram Shape2: (249, 64, 1)
# Wav Shape: (32000,)
# STFT Shape1: (249, 129)
# STFT Shape2: (249, 129)
# Mel Filterbank Shape: (129, 64)
# Mel Spectrogram Shape1: (249, 64)
# Mel Spectrogram Shape2: (249, 64, 1)

# %%
print(nspectrogram.shape)
plt.figure(figsize=(30,20))
plt.imshow(tf.transpose(nspectrogram)[0])
plt.show()
# Out:
# (249, 64, 1)

# %%
nspectrogram = nspectrogram[np.newaxis, :]
spectrogram = spectrogram[np.newaxis, :]

# %%
print(nspectrogram.shape)
print(spectrogram.shape)
# Out:
# (1, 249, 64, 1)
# (1, 249, 64, 1)

# %%
yhat0 = loaded_model.predict(nspectrogram)
yhat1 = loaded_model.predict(spectrogram)

# %%
print(yhat0)
print(yhat1)
# Out:
# [[1.]]
# [[1.]]

# %%
results = []

def create_results(dataset):
    for i in dataset:
        filepath = i[0]
        filename = filepath.replace('belize-data\\Validation data\\','')
        label = i[1]
        wav = load_wav_8k_mono(filepath)
        spectrogram = preprocess_mel(wav)
        spectrogram = spectrogram[np.newaxis, :]
        yhat = loaded_model.predict(spectrogram)
        results.append((filename, yhat, label))
    return results

# %%
def load_wav_8k_mono(filename):
    try:
        file_contents = tf.io.read_file(filename)
        wav, sample_rate = tf.audio.decode_wav(file_contents, desired_channels=1)
        sample_rate = tf.cast(sample_rate, dtype=tf.int64)
        if sample_rate != 8000:
            wav = tfio.audio.resample(wav, rate_in=sample_rate, rate_out=8000)
        wav = tf.squeeze(wav, axis=-1)
    except Exception as e:
        print(f"Invalid file: {filename} - {e}")
    return wav

# %%
sample_rate = 8000
mel_spec_length = 32000
frame_length = 256
frame_step = 128
mel_bins = 64
upper_edge = 4000
lower_edge = 0

# %%
def preprocess_mel(file_path, label):
    # load wav and make sure length is proper
    if isinstance(file_path, str):
        try:
            wav, label = load_wav_8k_mono(file_path)
        except Exception as e:
            print(f"Failed to load wav file at {file_path} - {e}")
    else:
        wav = file_path

    if len(wav) > 32000:
        wav = wav[:mel_spec_length]
    if len(wav) < 32000:
        try:
            zero_padding = tf.zeros([mel_spec_length] - tf.shape(wav), dtype=tf.float32)
            wav = tf.concat([zero_padding, wav], 0)
        except Exception as e:
            print(f"Failed to pad wav file at {file_path} - {e}")
    
    # create the spectrogram
    print("Wav Shape:", wav.shape)
    spectrogram = tf.signal.stft(wav, frame_length, frame_step, window_fn=tf.signal.hann_window)
    print("STFT Shape1:", spectrogram.shape)
    spectrogram = tf.abs(spectrogram)
    print("STFT Shape2:", spectrogram.shape)

    # create the mel filterbank
    spec_bins = frame_length // 2 + 1  # Derived from frame length
    mel_filterbank = tf.signal.linear_to_mel_weight_matrix(
        mel_bins,
        spec_bins,
        sample_rate,
        lower_edge,
        upper_edge,
    )
    print("Mel Filterbank Shape:", mel_filterbank.shape)
    
    # create the mel spectrogram
    mel_spectrogram = tf.matmul(spectrogram, mel_filterbank)
    print("Mel Spectrogram Shape1:", mel_spectrogram.shape)

    # add a dimension
    mel_spectrogram = tf.expand_dims(mel_spectrogram, axis=2)
    print("Mel Spectrogram Shape2:", mel_spectrogram.shape)

    return mel_spectrogram, label
