# %%
# !pip install tensorflow==2.8.0
# !pip install tensorflow_io==0.25.0
# !pip install matplotlib
# !pip install librosa
# Out:
# ...
#   Using cached librosa-0.10.2.post1-py3-none-any.whl.metadata (8.6 kB)
# ...
#   Using cached audioread-3.0.1-py3-none-any.whl.metadata (8.4 kB)
# ...
#   Using cached scikit_learn-1.5.2-cp310-cp310-win_amd64.whl.metadata (13 kB)
# ...
#   Using cached joblib-1.4.2-py3-none-any.whl.metadata (5.4 kB)
# ...
#   Using cached numba-0.60.0-cp310-cp310-win_amd64.whl.metadata (2.8 kB)
# ...
#   Using cached soundfile-0.12.1-py2.py3-none-win_amd64.whl.metadata (14 kB)
# ...
#   Using cached pooch-1.8.2-py3-none-any.whl.metadata (10 kB)
# ...
#   Using cached soxr-0.5.0.post1-cp310-cp310-win_amd64.whl.metadata (5.6 kB)
# ...
#   Using cached lazy_loader-0.4-py3-none-any.whl.metadata (7.6 kB)
# ...
#   Using cached msgpack-1.1.0-cp310-cp310-win_amd64.whl.metadata (8.6 kB)
# ...
#   Using cached llvmlite-0.43.0-cp310-cp310-win_amd64.whl.metadata (4.9 kB)
# ...
#   Using cached threadpoolctl-3.5.0-py3-none-any.whl.metadata (13 kB)
# ...
# Using cached librosa-0.10.2.post1-py3-none-any.whl (260 kB)
# Using cached audioread-3.0.1-py3-none-any.whl (23 kB)
# ...

# %%
# !pip list
# Out:
# Package                      Version
# ---------------------------- -------------------
# absl-py                      2.1.0
# aiohappyeyeballs             2.4.0
# aiohttp                      3.10.5
# aiosignal                    1.2.0
# anyio                        4.6.2
# argon2-cffi                  21.3.0
# argon2-cffi-bindings         21.2.0
# asttokens                    2.0.5
# astunparse                   1.6.3
# async-lru                    2.0.4
# async-timeout                4.0.3
# attrs                        24.2.0
# audioread                    3.0.1
# Babel                        2.11.0
# beautifulsoup4               4.12.3
# bleach                       6.2.0
# blinker                      1.6.2
# Brotli                       1.0.9
# cachetools                   5.3.3
# certifi                      2024.8.30
# cffi                         1.17.1
# charset-normalizer           3.3.2
# click                        8.1.7
# colorama                     0.4.6
# ...

# %%
import os
from matplotlib import pyplot as plt
import tensorflow as tf
import tensorflow_io as tfio
import librosa
import numpy as np

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, Dense, Flatten
from tensorflow.keras.callbacks import ModelCheckpoint

# %%
background_path = os.path.join('\\', 'Users', 'foxir', 'OneDrive', 'Desktop', 'Smart Rock', 'gunshot', 'model', 'Training data', 'Background','5B1E8AFA.wav')

# %%
CAPUCHIN_FILE = os.path.join('\\', 'Users', 'foxir', 'OneDrive', 'Desktop', 'Smart Rock', 'capuchinClassification', 'data', 'Parsed_Capuchinbird_Clips', 'XC3776-3.wav')
NOT_CAPUCHIN_FILE = os.path.join('\\', 'Users', 'foxir', 'OneDrive', 'Desktop', 'Smart Rock', 'capuchinClassification', 'data', 'Parsed_Not_Capuchinbird_Clips', 'afternoon-birds-song-in-forest-0.wav')

# %%
background_path = CAPUCHIN_FILE

# %%
try:
    file_contents = tf.io.read_file(background_path)
    wav, sample_rate = tf.audio.decode_wav(file_contents, desired_channels=1)
except tf.errors.NotFoundError as e:
    print(f"Error: {e}")

# %%
print(sample_rate)
# Out:
# tf.Tensor(44100, shape=(), dtype=int32)
